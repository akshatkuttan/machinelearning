# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from catboost import CatBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
import shap
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn.neural_network import MLPClassifier

# Read data from CSV file
df = pd.read_csv("C:\\Users\\USER\\Desktop\\assin ml\\archive (6)\\Data\\features_3_sec.csv")

# Encode categorical variables


# Encode the categorical column 'label'

label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['label'])
target_column = 'label'
# Split the data into features (X) and target variable (y)
X = df.drop(['filename', target_column], axis=1)
y = df[target_column]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)




# Create Random Forest classifier and fit it to the training data
random_forest_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest_classifier.fit(X_train, y_train)

# Predictions on training and testing data
y_train_pred_rf = random_forest_classifier.predict(X_train)
y_test_pred_rf = random_forest_classifier.predict(X_test)

# Accuracy for training and testing data
accuracy_X_rf = accuracy_score(y_train, y_train_pred_rf)
accuracy_y_rf = accuracy_score(y_test, y_test_pred_rf)

# precision, recall, and F1 score for training data
precision_X_rf = precision_score(y_train, y_train_pred_rf,average='weighted')
recall_X_rf = recall_score(y_train, y_train_pred_rf,average='weighted')
f1_X_rf = f1_score(y_train, y_train_pred_rf,average='weighted')

# precision, recall, and F1 score for testing data
precision_y_rf = precision_score(y_test, y_test_pred_rf,average='weighted')
recall_y_rf = recall_score(y_test, y_test_pred_rf,average='weighted')
f1_y_rf = f1_score(y_test, y_test_pred_rf,average='weighted')

print("Accuracy (Training Data):", accuracy_X_rf)
print("Precision (Training Data):", precision_X_rf)
print("Recall (Training Data):", recall_X_rf)
print("F1 Score (Training Data):", f1_X_rf)

print("\nAccuracy (Testing Data):", accuracy_y_rf)
print("Precision (Testing Data):", precision_y_rf)
print("Recall (Testing Data):", recall_y_rf)
print("F1 Score (Testing Data):", f1_y_rf)





# Create Gradient Boosting classifier and fit it to the training data
gradient_boosting_classifier = GradientBoostingClassifier(random_state=42)
gradient_boosting_classifier.fit(X_train, y_train)

# Predictions on training and testing data
y_train_pred_gb = gradient_boosting_classifier.predict(X_train)
y_test_pred_gb = gradient_boosting_classifier.predict(X_test)

# Accuracy for training and testing data
accuracy_X_gb = accuracy_score(y_train, y_train_pred_gb)
accuracy_y_gb = accuracy_score(y_test, y_test_pred_gb)

#precision, recall, and F1 score for training data
precision_X_gb = precision_score(y_train, y_train_pred_gb,average='weighted')
recall_X_gb = recall_score(y_train, y_train_pred_gb,average='weighted')
f1_X_gb = f1_score(y_train, y_train_pred_gb,average='weighted')

#precision, recall, and F1 score for testing data
precision_y_gb = precision_score(y_test, y_test_pred_gb,average='weighted')
recall_y_gb = recall_score(y_test, y_test_pred_gb,average='weighted')
f1_y_gb = f1_score(y_test, y_test_pred_gb,average='weighted')

print("Accuracy (Training Data):", accuracy_X_gb)
print("Precision (Training Data):", precision_X_gb)
print("Recall (Training Data):", recall_X_gb)
print("F1 Score (Training Data):", f1_X_gb)

print("\nAccuracy (Testing Data):", accuracy_y_gb)
print("Precision (Testing Data):", precision_y_gb)
print("Recall (Testing Data):", recall_y_gb)
print("F1 Score (Testing Data):", f1_y_gb)




# Create Decision Tree classifier and fit it to the training data
decision_tree_classifier = DecisionTreeClassifier(random_state=42)
decision_tree_classifier.fit(X_train, y_train)

# Predictions on training and testing data
y_train_pred_dt = decision_tree_classifier.predict(X_train)
y_test_pred_dt = decision_tree_classifier.predict(X_test)

# Accuracy for training and testing data
accuracy_X_dt = accuracy_score(y_train, y_train_pred_dt)
accuracy_y_dt = accuracy_score(y_test, y_test_pred_dt)

# precision, recall, and F1 score for training data
precision_X_dt = precision_score(y_train, y_train_pred_dt,average='weighted')
recall_X_dt = recall_score(y_train, y_train_pred_dt,average='weighted')
f1_X_dt = f1_score(y_train, y_train_pred_dt,average='weighted')

#precision, recall, and F1 score for testing data
precision_y_dt = precision_score(y_test, y_test_pred_dt,average='weighted')
recall_y_dt = recall_score(y_test, y_test_pred_dt,average='weighted')
f1_y_dt = f1_score(y_test, y_test_pred_dt,average='weighted')

print("Accuracy (Training Data):", accuracy_X_dt)
print("Precision (Training Data):", precision_X_dt)
print("Recall (Training Data):", recall_X_dt)
print("F1 Score (Training Data):", f1_X_dt)

print("\nAccuracy (Testing Data):", accuracy_y_dt)
print("Precision (Testing Data):", precision_y_dt)
print("Recall (Testing Data):", recall_y_dt)
print("F1 Score (Testing Data):", f1_y_dt)




# Create SVM classifier and fit it to the training data
svm_classifier = SVC(kernel='rbf', random_state=42)
svm_classifier.fit(X_train, y_train)

# Predictions on training and testing data
y_train_pred_svm = svm_classifier.predict(X_train)
y_test_pred_svm = svm_classifier.predict(X_test)

# Accuracy for training and testing data
accuracy_X_svm = accuracy_score(y_train, y_train_pred_svm)
accuracy_y_svm = accuracy_score(y_test, y_test_pred_svm)

#precision, recall, and F1 score for training data
precision_X_svm = precision_score(y_train, y_train_pred_svm,average='weighted')
recall_X_svm = recall_score(y_train, y_train_pred_svm,average='weighted')
f1_X_svm = f1_score(y_train, y_train_pred_svm,average='weighted')

#precision, recall, and F1 score for testing data
precision_y_svm = precision_score(y_test, y_test_pred_svm,average='weighted')
recall_y_svm = recall_score(y_test, y_test_pred_svm,average='weighted')
f1_y_svm = f1_score(y_test, y_test_pred_svm,average='weighted')

print("Accuracy (Training Data):", accuracy_X_svm)
print("Precision (Training Data):", precision_X_svm)
print("Recall (Training Data):", recall_X_svm)
print("F1 Score (Training Data):", f1_X_svm)

print("\nAccuracy (Testing Data):", accuracy_y_svm)
print("Precision (Testing Data):", precision_y_svm)
print("Recall (Testing Data):", recall_y_svm)
print("F1 Score (Testing Data):", f1_y_svm)




# Create Naive Bayes classifier and fit it to the training data
naive_bayes_classifier = GaussianNB()
naive_bayes_classifier.fit(X_train, y_train)

# Predictions on training and testing data
y_train_pred_nb = naive_bayes_classifier.predict(X_train)
y_test_pred_nb = naive_bayes_classifier.predict(X_test)

# Accuracy for training and testing data
accuracy_X_nb = accuracy_score(y_train, y_train_pred_nb)
accuracy_y_nb = accuracy_score(y_test, y_test_pred_nb)

#precision, recall, and F1 score for training data
precision_X_nb = precision_score(y_train, y_train_pred_nb,average='weighted')
recall_X_nb = recall_score(y_train, y_train_pred_nb,average='weighted')
f1_X_nb = f1_score(y_train, y_train_pred_nb,average='weighted')

# precision, recall, and F1 score for testing data
precision_y_nb = precision_score(y_test, y_test_pred_nb,average='weighted')
recall_y_nb = recall_score(y_test, y_test_pred_nb,average='weighted')
f1_y_nb = f1_score(y_test, y_test_pred_nb,average='weighted')

print("Accuracy (Training Data):", accuracy_X_nb)
print("Precision (Training Data):", precision_X_nb)
print("Recall (Training Data):", recall_X_nb)
print("F1 Score (Training Data):", f1_X_nb)

print("\nAccuracy (Testing Data):", accuracy_y_nb)
print("Precision (Testing Data):", precision_y_nb)
print("Recall (Testing Data):", recall_y_nb)
print("F1 Score (Testing Data):", f1_y_nb)




# Create CatBoost classifier and fit it to the training data
catboost_classifier = CatBoostClassifier(random_state=42)
catboost_classifier.fit(X_train, y_train)

# Predictions on training and testing data
y_train_pred_cb = catboost_classifier.predict(X_train)
y_test_pred_cb = catboost_classifier.predict(X_test)

# Accuracy for training and testing data
accuracy_X_cb = accuracy_score(y_train, y_train_pred_cb)
accuracy_y_cb = accuracy_score(y_test, y_test_pred_cb)

# Compute precision, recall, and F1 score for training data
precision_X_cb = precision_score(y_train, y_train_pred_cb,average='weighted')
recall_X_cb = recall_score(y_train, y_train_pred_cb,average='weighted')
f1_X_cb = f1_score(y_train, y_train_pred_cb,average='weighted')

# Compute precision, recall, and F1 score for testing data
precision_y_cb = precision_score(y_test, y_test_pred_cb,average='weighted')
recall_y_cb = recall_score(y_test, y_test_pred_cb,average='weighted')
f1_y_cb = f1_score(y_test, y_test_pred_cb,average='weighted')

print("Accuracy (Training Data):", accuracy_X_cb)
print("Precision (Training Data):", precision_X_cb)
print("Recall (Training Data):", recall_X_cb)
print("F1 Score (Training Data):", f1_X_cb)

print("\nAccuracy (Testing Data):", accuracy_y_cb)
print("Precision (Testing Data):", precision_y_cb)
print("Recall (Testing Data):", recall_y_cb)
print("F1 Score (Testing Data):", f1_y_cb)




# Create AdaBoost classifier and fit it to the training data
adaboost_classifier = AdaBoostClassifier(random_state=42)
adaboost_classifier.fit(X_train, y_train)

# Predictions on training and testing data
y_train_pred_ab = adaboost_classifier.predict(X_train)
y_test_pred_ab = adaboost_classifier.predict(X_test)

# Accuracy for training and testing data
accuracy_X_ab = accuracy_score(y_train, y_train_pred_ab)
accuracy_y_ab = accuracy_score(y_test, y_test_pred_ab)

# Compute precision, recall, and F1 score for training data
precision_X_ab = precision_score(y_train, y_train_pred_ab,average='weighted')
recall_X_ab = recall_score(y_train, y_train_pred_ab,average='weighted')
f1_X_ab = f1_score(y_train, y_train_pred_ab,average='weighted')

# Compute precision, recall, and F1 score for testing data
precision_y_ab = precision_score(y_test, y_test_pred_ab,average='weighted')
recall_y_ab = recall_score(y_test, y_test_pred_ab,average='weighted')
f1_y_ab = f1_score(y_test, y_test_pred_ab,average='weighted')

print("Accuracy (Training Data):", accuracy_X_ab)
print("Precision (Training Data):", precision_X_ab)
print("Recall (Training Data):", recall_X_ab)
print("F1 Score (Training Data):", f1_X_ab)

print("\nAccuracy (Testing Data):", accuracy_y_ab)
print("Precision (Testing Data):", precision_y_ab)
print("Recall (Testing Data):", recall_y_ab)
print("F1 Score (Testing Data):", f1_y_ab)



# Create XGBoost classifier and fit it to the training data
xgb_classifier = XGBClassifier(random_state=42)
xgb_classifier.fit(X_train, y_train)

# Predictions on training and testing data
y_train_pred_xgb = xgb_classifier.predict(X_train)
y_test_pred_xgb = xgb_classifier.predict(X_test)

# Accuracy for training and testing data
accuracy_X_xgb = accuracy_score(y_train, y_train_pred_xgb)
accuracy_y_xgb = accuracy_score(y_test, y_test_pred_xgb)


# Compute precision, recall, and F1 score for training data
precision_X_xgb = precision_score(y_train, y_train_pred_xgb,average='weighted')
recall_X_xgb = recall_score(y_train, y_train_pred_xgb,average='weighted')
f1_X_xgb = f1_score(y_train, y_train_pred_xgb,average='weighted')

# Compute precision, recall, and F1 score for testing data
precision_y_xgb = precision_score(y_test, y_test_pred_xgb,average='weighted')
recall_y_xgb = recall_score(y_test, y_test_pred_xgb,average='weighted')
f1_y_xgb = f1_score(y_test, y_test_pred_xgb,average='weighted')

print("Accuracy (Training Data):", accuracy_X_xgb)
print("Precision (Training Data):", precision_X_xgb)
print("Recall (Training Data):", recall_X_xgb)
print("F1 Score (Training Data):", f1_X_xgb)

print("\nAccuracy (Testing Data):", accuracy_y_xgb)
print("Precision (Testing Data):", precision_y_xgb)
print("Recall (Testing Data):", recall_y_xgb)
print("F1 Score (Testing Data):", f1_y_xgb)





# Define the parameter distribution for the RandomizedSearchCV
param_dist = {
    'hidden_layer_sizes': [(50,), (100,), (150,), (200,)],
    'activation': ['logistic', 'relu', 'tanh'],
    'solver': ['adam', 'sgd'],  # Try different solvers
    'alpha': [0.0001, 0.001, 0.01, 0.1],
    'max_iter': [1000, 5000, 10000, 15000]
}


# Create a RandomizedSearchCV object for hyperparameter tuning
random_search = RandomizedSearchCV(MLPClassifier(random_state=1, max_iter=2000), param_distributions=param_dist, n_iter=20, cv=5, random_state=42)


# Perform the randomized search over the parameter space
random_search.fit(X_train, y_train)

# Get the best parameters and best score found during the search
best_params = random_search.best_params_
best_score = random_search.best_score_

# Print the best parameters and best score
print("Best Parameters:", best_params)
print("Best Score:", best_score)


random_forest_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
random_forest_classifier.fit(X_train, y_train)

# Predictions on testing data
y_test_pred_rf = random_forest_classifier.predict(X_test)

# Accuracy for testing data
accuracy_test = accuracy_score(y_test, y_test_pred_rf)
print("\nAccuracy (Testing Data):", accuracy_test)

# Initialize SHAP explainer
explainer = shap.TreeExplainer(random_forest_classifier)

# Generate SHAP values
shap_values = explainer.shap_values(X_test)

# Visualize feature importances
shap.summary_plot(shap_values, X_test)
# Out:
# Accuracy (Training Data): 0.9993326659993327
# Precision (Training Data): 0.9993370134521058
# Recall (Training Data): 0.9993326659993327
# F1 Score (Training Data): 0.9993326515567493
#
# Accuracy (Testing Data): 0.8518518518518519
# Precision (Testing Data): 0.8531055176623279
# Recall (Testing Data): 0.8518518518518519
# F1 Score (Testing Data): 0.8508921446317674
# Accuracy (Training Data): 0.9688021354688021
# Precision (Training Data): 0.9689297763953876
# Recall (Training Data): 0.9688021354688021
# F1 Score (Training Data): 0.9687601388223387
#
# Accuracy (Testing Data): 0.8225725725725725
# Precision (Testing Data): 0.8231649185613363
# Recall (Testing Data): 0.8225725725725725
# F1 Score (Testing Data): 0.822245614319493
# Accuracy (Training Data): 0.9993326659993327
# Precision (Training Data): 0.9993370134521058
# Recall (Training Data): 0.9993326659993327
# F1 Score (Training Data): 0.9993326515567493
#
# Accuracy (Testing Data): 0.6276276276276276
# Precision (Testing Data): 0.6303326906577887
# Recall (Testing Data): 0.6276276276276276
# F1 Score (Testing Data): 0.6273673418637964
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\USER\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy (Training Data): 0.29362696029362695
# Precision (Training Data): 0.2696650607232962
# Recall (Training Data): 0.29362696029362695
# F1 Score (Training Data): 0.2483291336767181
#
# Accuracy (Testing Data): 0.2872872872872873
# Precision (Testing Data): 0.23024352933456216
# Recall (Testing Data): 0.2872872872872873
# F1 Score (Testing Data): 0.23692719432459317
# Accuracy (Training Data): 0.42809476142809477
# Precision (Training Data): 0.45343810773602883
# Recall (Training Data): 0.42809476142809477
# F1 Score (Training Data): 0.40902105505008957
#
# Accuracy (Testing Data): 0.4336836836836837
# Precision (Testing Data): 0.457645082610921
# Recall (Testing Data): 0.4336836836836837
# F1 Score (Testing Data): 0.41381378254140694
# Learning rate set to 0.086694
# 0:	learn: 2.1654586	total: 104ms	remaining: 1m 44s
# 1:	learn: 2.0617745	total: 200ms	remaining: 1m 39s
# 2:	learn: 1.9682669	total: 295ms	remaining: 1m 37s
# 3:	learn: 1.8881777	total: 388ms	remaining: 1m 36s
# 4:	learn: 1.8191248	total: 481ms	remaining: 1m 35s
# 5:	learn: 1.7546575	total: 572ms	remaining: 1m 34s
# 6:	learn: 1.6975479	total: 666ms	remaining: 1m 34s
# 7:	learn: 1.6498759	total: 762ms	remaining: 1m 34s
# 8:	learn: 1.6048351	total: 853ms	remaining: 1m 33s
# 9:	learn: 1.5636661	total: 952ms	remaining: 1m 34s
# 10:	learn: 1.5188063	total: 1.06s	remaining: 1m 35s
# 11:	learn: 1.4833524	total: 1.16s	remaining: 1m 35s
# 12:	learn: 1.4527033	total: 1.26s	remaining: 1m 35s
# 13:	learn: 1.4267128	total: 1.36s	remaining: 1m 35s
# 14:	learn: 1.3988490	total: 1.45s	remaining: 1m 35s
# 15:	learn: 1.3704578	total: 1.54s	remaining: 1m 34s
# 16:	learn: 1.3452959	total: 1.64s	remaining: 1m 35s
# 17:	learn: 1.3206625	total: 1.74s	remaining: 1m 34s
# 18:	learn: 1.2977109	total: 1.84s	remaining: 1m 34s
# 19:	learn: 1.2759711	total: 1.93s	remaining: 1m 34s
# 20:	learn: 1.2578815	total: 2.02s	remaining: 1m 34s
# 21:	learn: 1.2386323	total: 2.12s	remaining: 1m 34s
# 22:	learn: 1.2193463	total: 2.21s	remaining: 1m 33s
# 23:	learn: 1.2007124	total: 2.3s	remaining: 1m 33s
# 24:	learn: 1.1848191	total: 2.39s	remaining: 1m 33s
# 25:	learn: 1.1689557	total: 2.49s	remaining: 1m 33s
# 26:	learn: 1.1458694	total: 2.59s	remaining: 1m 33s
# 27:	learn: 1.1308861	total: 2.69s	remaining: 1m 33s
# 28:	learn: 1.1165179	total: 2.81s	remaining: 1m 34s
# 29:	learn: 1.1041900	total: 2.91s	remaining: 1m 34s
# 30:	learn: 1.0890256	total: 3.01s	remaining: 1m 33s
# 31:	learn: 1.0741733	total: 3.11s	remaining: 1m 34s
# 32:	learn: 1.0637242	total: 3.21s	remaining: 1m 34s
# 33:	learn: 1.0453184	total: 3.31s	remaining: 1m 34s
# 34:	learn: 1.0313798	total: 3.41s	remaining: 1m 34s
# 35:	learn: 1.0240217	total: 3.51s	remaining: 1m 33s
# 36:	learn: 1.0141852	total: 3.61s	remaining: 1m 33s
# 37:	learn: 1.0035866	total: 3.7s	remaining: 1m 33s
# 38:	learn: 0.9915951	total: 3.8s	remaining: 1m 33s
# 39:	learn: 0.9804201	total: 3.9s	remaining: 1m 33s
# 40:	learn: 0.9717589	total: 4s	remaining: 1m 33s
# 41:	learn: 0.9631360	total: 4.1s	remaining: 1m 33s
# 42:	learn: 0.9534043	total: 4.2s	remaining: 1m 33s
# 43:	learn: 0.9446106	total: 4.3s	remaining: 1m 33s
# 44:	learn: 0.9347542	total: 4.4s	remaining: 1m 33s
# 45:	learn: 0.9251294	total: 4.5s	remaining: 1m 33s
# 46:	learn: 0.9167633	total: 4.6s	remaining: 1m 33s
# 47:	learn: 0.9107034	total: 4.72s	remaining: 1m 33s
# 48:	learn: 0.9028082	total: 4.83s	remaining: 1m 33s
# 49:	learn: 0.8963068	total: 4.92s	remaining: 1m 33s
# 50:	learn: 0.8875366	total: 5.02s	remaining: 1m 33s
# 51:	learn: 0.8819285	total: 5.12s	remaining: 1m 33s
# 52:	learn: 0.8758147	total: 5.21s	remaining: 1m 33s
# 53:	learn: 0.8684299	total: 5.31s	remaining: 1m 32s
# 54:	learn: 0.8617523	total: 5.4s	remaining: 1m 32s
# 55:	learn: 0.8555782	total: 5.5s	remaining: 1m 32s
# 56:	learn: 0.8488765	total: 5.58s	remaining: 1m 32s
# 57:	learn: 0.8420179	total: 5.68s	remaining: 1m 32s
# 58:	learn: 0.8361591	total: 5.78s	remaining: 1m 32s
# 59:	learn: 0.8313941	total: 5.88s	remaining: 1m 32s
# 60:	learn: 0.8265504	total: 5.97s	remaining: 1m 31s
# 61:	learn: 0.8190390	total: 6.07s	remaining: 1m 31s
# 62:	learn: 0.8127546	total: 6.16s	remaining: 1m 31s
# 63:	learn: 0.8077535	total: 6.26s	remaining: 1m 31s
# 64:	learn: 0.8027216	total: 6.36s	remaining: 1m 31s
# 65:	learn: 0.7967245	total: 6.45s	remaining: 1m 31s
# 66:	learn: 0.7922345	total: 6.55s	remaining: 1m 31s
# 67:	learn: 0.7875389	total: 6.65s	remaining: 1m 31s
# 68:	learn: 0.7807067	total: 6.77s	remaining: 1m 31s
# 69:	learn: 0.7755726	total: 6.87s	remaining: 1m 31s
# 70:	learn: 0.7703086	total: 6.97s	remaining: 1m 31s
# 71:	learn: 0.7662487	total: 7.07s	remaining: 1m 31s
# 72:	learn: 0.7603829	total: 7.16s	remaining: 1m 30s
# 73:	learn: 0.7557841	total: 7.25s	remaining: 1m 30s
# 74:	learn: 0.7480715	total: 7.35s	remaining: 1m 30s
# 75:	learn: 0.7432524	total: 7.45s	remaining: 1m 30s
# 76:	learn: 0.7392706	total: 7.54s	remaining: 1m 30s
# 77:	learn: 0.7345667	total: 7.64s	remaining: 1m 30s
# 78:	learn: 0.7312423	total: 7.74s	remaining: 1m 30s
# 79:	learn: 0.7265949	total: 7.84s	remaining: 1m 30s
# 80:	learn: 0.7222355	total: 7.94s	remaining: 1m 30s
# 81:	learn: 0.7179490	total: 8.03s	remaining: 1m 29s
# 82:	learn: 0.7145915	total: 8.13s	remaining: 1m 29s
# 83:	learn: 0.7089378	total: 8.23s	remaining: 1m 29s
# 84:	learn: 0.7046366	total: 8.32s	remaining: 1m 29s
# 85:	learn: 0.7005420	total: 8.43s	remaining: 1m 29s
# 86:	learn: 0.6963200	total: 8.53s	remaining: 1m 29s
# 87:	learn: 0.6919188	total: 8.63s	remaining: 1m 29s
# 88:	learn: 0.6870683	total: 8.73s	remaining: 1m 29s
# 89:	learn: 0.6837312	total: 8.83s	remaining: 1m 29s
# 90:	learn: 0.6803112	total: 8.93s	remaining: 1m 29s
# 91:	learn: 0.6769849	total: 9.02s	remaining: 1m 29s
# 92:	learn: 0.6727342	total: 9.12s	remaining: 1m 28s
# 93:	learn: 0.6674334	total: 9.22s	remaining: 1m 28s
# 94:	learn: 0.6638987	total: 9.32s	remaining: 1m 28s
# 95:	learn: 0.6577790	total: 9.43s	remaining: 1m 28s
# 96:	learn: 0.6540503	total: 9.53s	remaining: 1m 28s
# 97:	learn: 0.6499240	total: 9.63s	remaining: 1m 28s
# 98:	learn: 0.6468769	total: 9.73s	remaining: 1m 28s
# 99:	learn: 0.6435085	total: 9.83s	remaining: 1m 28s
# 100:	learn: 0.6392191	total: 9.93s	remaining: 1m 28s
# 101:	learn: 0.6352564	total: 10s	remaining: 1m 28s
# 102:	learn: 0.6318672	total: 10.1s	remaining: 1m 28s
# 103:	learn: 0.6270618	total: 10.2s	remaining: 1m 28s
# 104:	learn: 0.6252223	total: 10.3s	remaining: 1m 27s
# 105:	learn: 0.6230605	total: 10.4s	remaining: 1m 27s
# 106:	learn: 0.6195682	total: 10.5s	remaining: 1m 27s
# 107:	learn: 0.6152407	total: 10.6s	remaining: 1m 27s
# 108:	learn: 0.6132016	total: 10.7s	remaining: 1m 27s
# 109:	learn: 0.6113237	total: 10.8s	remaining: 1m 27s
# 110:	learn: 0.6071956	total: 10.9s	remaining: 1m 27s
# 111:	learn: 0.6027309	total: 11s	remaining: 1m 27s
# 112:	learn: 0.5999247	total: 11.1s	remaining: 1m 26s
# 113:	learn: 0.5970776	total: 11.2s	remaining: 1m 26s
# 114:	learn: 0.5938427	total: 11.3s	remaining: 1m 26s
# 115:	learn: 0.5915863	total: 11.4s	remaining: 1m 26s
# 116:	learn: 0.5875918	total: 11.5s	remaining: 1m 26s
# 117:	learn: 0.5842821	total: 11.6s	remaining: 1m 26s
# 118:	learn: 0.5812136	total: 11.7s	remaining: 1m 26s
# 119:	learn: 0.5776832	total: 11.8s	remaining: 1m 26s
# 120:	learn: 0.5725912	total: 11.9s	remaining: 1m 26s
# 121:	learn: 0.5691780	total: 12s	remaining: 1m 26s
# 122:	learn: 0.5667396	total: 12.1s	remaining: 1m 26s
# 123:	learn: 0.5641245	total: 12.2s	remaining: 1m 26s
# 124:	learn: 0.5610356	total: 12.3s	remaining: 1m 26s
# 125:	learn: 0.5593271	total: 12.4s	remaining: 1m 25s
# 126:	learn: 0.5559971	total: 12.5s	remaining: 1m 25s
# 127:	learn: 0.5529210	total: 12.6s	remaining: 1m 25s
# 128:	learn: 0.5502753	total: 12.7s	remaining: 1m 25s
# 129:	learn: 0.5479223	total: 12.8s	remaining: 1m 25s
# 130:	learn: 0.5455986	total: 12.9s	remaining: 1m 25s
# 131:	learn: 0.5429896	total: 13s	remaining: 1m 25s
# 132:	learn: 0.5399473	total: 13.1s	remaining: 1m 25s
# 133:	learn: 0.5371290	total: 13.2s	remaining: 1m 25s
# 134:	learn: 0.5341879	total: 13.3s	remaining: 1m 25s
# 135:	learn: 0.5320636	total: 13.4s	remaining: 1m 25s
# 136:	learn: 0.5286971	total: 13.5s	remaining: 1m 25s
# 137:	learn: 0.5267976	total: 13.6s	remaining: 1m 24s
# 138:	learn: 0.5247859	total: 13.7s	remaining: 1m 24s
# 139:	learn: 0.5220011	total: 13.8s	remaining: 1m 24s
# 140:	learn: 0.5202355	total: 13.9s	remaining: 1m 24s
# 141:	learn: 0.5180217	total: 14s	remaining: 1m 24s
# 142:	learn: 0.5158428	total: 14.1s	remaining: 1m 24s
# 143:	learn: 0.5136839	total: 14.2s	remaining: 1m 24s
# 144:	learn: 0.5108626	total: 14.3s	remaining: 1m 24s
# 145:	learn: 0.5090894	total: 14.4s	remaining: 1m 24s
# 146:	learn: 0.5059608	total: 14.5s	remaining: 1m 24s
# 147:	learn: 0.5038958	total: 14.6s	remaining: 1m 24s
# 148:	learn: 0.5027032	total: 14.7s	remaining: 1m 24s
# 149:	learn: 0.5006857	total: 14.8s	remaining: 1m 24s
# 150:	learn: 0.4999934	total: 14.9s	remaining: 1m 23s
# 151:	learn: 0.4973124	total: 15s	remaining: 1m 23s
# 152:	learn: 0.4948169	total: 15.1s	remaining: 1m 23s
# 153:	learn: 0.4927744	total: 15.2s	remaining: 1m 23s
# 154:	learn: 0.4900027	total: 15.4s	remaining: 1m 23s
# 155:	learn: 0.4862118	total: 15.5s	remaining: 1m 23s
# 156:	learn: 0.4845729	total: 15.6s	remaining: 1m 23s
# 157:	learn: 0.4828260	total: 15.7s	remaining: 1m 23s
# 158:	learn: 0.4804645	total: 15.8s	remaining: 1m 23s
# 159:	learn: 0.4783716	total: 15.9s	remaining: 1m 23s
# 160:	learn: 0.4755939	total: 16s	remaining: 1m 23s
# 161:	learn: 0.4726640	total: 16.1s	remaining: 1m 23s
# 162:	learn: 0.4712401	total: 16.2s	remaining: 1m 23s
# 163:	learn: 0.4684593	total: 16.3s	remaining: 1m 22s
# 164:	learn: 0.4662538	total: 16.4s	remaining: 1m 22s
# 165:	learn: 0.4641525	total: 16.5s	remaining: 1m 22s
# 166:	learn: 0.4617472	total: 16.6s	remaining: 1m 22s
# 167:	learn: 0.4593083	total: 16.7s	remaining: 1m 22s
# 168:	learn: 0.4573903	total: 16.8s	remaining: 1m 22s
# 169:	learn: 0.4555225	total: 16.8s	remaining: 1m 22s
# 170:	learn: 0.4541946	total: 16.9s	remaining: 1m 22s
# 171:	learn: 0.4530513	total: 17s	remaining: 1m 22s
# 172:	learn: 0.4516717	total: 17.1s	remaining: 1m 21s
# 173:	learn: 0.4498313	total: 17.2s	remaining: 1m 21s
# 174:	learn: 0.4481640	total: 17.3s	remaining: 1m 21s
# 175:	learn: 0.4472992	total: 17.4s	remaining: 1m 21s
# 176:	learn: 0.4458500	total: 17.5s	remaining: 1m 21s
# 177:	learn: 0.4440844	total: 17.6s	remaining: 1m 21s
# 178:	learn: 0.4422954	total: 17.7s	remaining: 1m 21s
# 179:	learn: 0.4405577	total: 17.8s	remaining: 1m 21s
# 180:	learn: 0.4393687	total: 17.9s	remaining: 1m 21s
# 181:	learn: 0.4371411	total: 18s	remaining: 1m 20s
# 182:	learn: 0.4354358	total: 18.1s	remaining: 1m 20s
# 183:	learn: 0.4338007	total: 18.2s	remaining: 1m 20s
# 184:	learn: 0.4318884	total: 18.3s	remaining: 1m 20s
# 185:	learn: 0.4306781	total: 18.4s	remaining: 1m 20s
# 186:	learn: 0.4281273	total: 18.5s	remaining: 1m 20s
# 187:	learn: 0.4268257	total: 18.6s	remaining: 1m 20s
# 188:	learn: 0.4251741	total: 18.6s	remaining: 1m 20s
# 189:	learn: 0.4233127	total: 18.7s	remaining: 1m 19s
# 190:	learn: 0.4219131	total: 18.8s	remaining: 1m 19s
# 191:	learn: 0.4201899	total: 18.9s	remaining: 1m 19s
# 192:	learn: 0.4188714	total: 19s	remaining: 1m 19s
# 193:	learn: 0.4168949	total: 19.1s	remaining: 1m 19s
# 194:	learn: 0.4155967	total: 19.2s	remaining: 1m 19s
# 195:	learn: 0.4138758	total: 19.3s	remaining: 1m 19s
# 196:	learn: 0.4126836	total: 19.4s	remaining: 1m 18s
# 197:	learn: 0.4114610	total: 19.5s	remaining: 1m 18s
# 198:	learn: 0.4097570	total: 19.6s	remaining: 1m 18s
# 199:	learn: 0.4087273	total: 19.6s	remaining: 1m 18s
# 200:	learn: 0.4064578	total: 19.7s	remaining: 1m 18s
# 201:	learn: 0.4053532	total: 19.8s	remaining: 1m 18s
# 202:	learn: 0.4042067	total: 19.9s	remaining: 1m 18s
# 203:	learn: 0.4026163	total: 20s	remaining: 1m 18s
# 204:	learn: 0.4016540	total: 20.1s	remaining: 1m 18s
# 205:	learn: 0.4002156	total: 20.2s	remaining: 1m 17s
# 206:	learn: 0.3990280	total: 20.3s	remaining: 1m 17s
# 207:	learn: 0.3963165	total: 20.4s	remaining: 1m 17s
# 208:	learn: 0.3939894	total: 20.5s	remaining: 1m 17s
# 209:	learn: 0.3926633	total: 20.6s	remaining: 1m 17s
# 210:	learn: 0.3914712	total: 20.7s	remaining: 1m 17s
# 211:	learn: 0.3903591	total: 20.8s	remaining: 1m 17s
# 212:	learn: 0.3892361	total: 20.9s	remaining: 1m 17s
# 213:	learn: 0.3879816	total: 21s	remaining: 1m 17s
# 214:	learn: 0.3867503	total: 21.1s	remaining: 1m 17s
# 215:	learn: 0.3857131	total: 21.2s	remaining: 1m 17s
# 216:	learn: 0.3840747	total: 21.3s	remaining: 1m 16s
# 217:	learn: 0.3820758	total: 21.4s	remaining: 1m 16s
# 218:	learn: 0.3814019	total: 21.5s	remaining: 1m 16s
# 219:	learn: 0.3802999	total: 21.6s	remaining: 1m 16s
# 220:	learn: 0.3791949	total: 21.7s	remaining: 1m 16s
# 221:	learn: 0.3777800	total: 21.8s	remaining: 1m 16s
# 222:	learn: 0.3768761	total: 21.9s	remaining: 1m 16s
# 223:	learn: 0.3756200	total: 22s	remaining: 1m 16s
# 224:	learn: 0.3741997	total: 22.1s	remaining: 1m 16s
# 225:	learn: 0.3730341	total: 22.2s	remaining: 1m 16s
# 226:	learn: 0.3718475	total: 22.3s	remaining: 1m 15s
# 227:	learn: 0.3707294	total: 22.4s	remaining: 1m 15s
# 228:	learn: 0.3693451	total: 22.5s	remaining: 1m 15s
# 229:	learn: 0.3680756	total: 22.6s	remaining: 1m 15s
# 230:	learn: 0.3666967	total: 22.7s	remaining: 1m 15s
# 231:	learn: 0.3656609	total: 22.8s	remaining: 1m 15s
# 232:	learn: 0.3643522	total: 22.9s	remaining: 1m 15s
# 233:	learn: 0.3637579	total: 23s	remaining: 1m 15s
# 234:	learn: 0.3629863	total: 23.1s	remaining: 1m 15s
# 235:	learn: 0.3615110	total: 23.2s	remaining: 1m 15s
# 236:	learn: 0.3601581	total: 23.3s	remaining: 1m 15s
# 237:	learn: 0.3593143	total: 23.4s	remaining: 1m 14s
# 238:	learn: 0.3578642	total: 23.5s	remaining: 1m 14s
# 239:	learn: 0.3567446	total: 23.6s	remaining: 1m 14s
# 240:	learn: 0.3549739	total: 23.7s	remaining: 1m 14s
# 241:	learn: 0.3538253	total: 23.8s	remaining: 1m 14s
# 242:	learn: 0.3526514	total: 23.9s	remaining: 1m 14s
# 243:	learn: 0.3522641	total: 24s	remaining: 1m 14s
# 244:	learn: 0.3514761	total: 24.1s	remaining: 1m 14s
# 245:	learn: 0.3503464	total: 24.2s	remaining: 1m 14s
# 246:	learn: 0.3495860	total: 24.3s	remaining: 1m 14s
# 247:	learn: 0.3487598	total: 24.4s	remaining: 1m 14s
# 248:	learn: 0.3477982	total: 24.5s	remaining: 1m 13s
# 249:	learn: 0.3471222	total: 24.6s	remaining: 1m 13s
# 250:	learn: 0.3457266	total: 24.7s	remaining: 1m 13s
# 251:	learn: 0.3446882	total: 24.8s	remaining: 1m 13s
# 252:	learn: 0.3440165	total: 24.9s	remaining: 1m 13s
# 253:	learn: 0.3423983	total: 25s	remaining: 1m 13s
# 254:	learn: 0.3414063	total: 25.1s	remaining: 1m 13s
# 255:	learn: 0.3400652	total: 25.2s	remaining: 1m 13s
# 256:	learn: 0.3389409	total: 25.3s	remaining: 1m 13s
# 257:	learn: 0.3380023	total: 25.4s	remaining: 1m 13s
# 258:	learn: 0.3371518	total: 25.5s	remaining: 1m 12s
# 259:	learn: 0.3365267	total: 25.6s	remaining: 1m 12s
# 260:	learn: 0.3351324	total: 25.7s	remaining: 1m 12s
# 261:	learn: 0.3338490	total: 25.8s	remaining: 1m 12s
# 262:	learn: 0.3326468	total: 25.9s	remaining: 1m 12s
# 263:	learn: 0.3318525	total: 26s	remaining: 1m 12s
# 264:	learn: 0.3308163	total: 26.1s	remaining: 1m 12s
# 265:	learn: 0.3295770	total: 26.2s	remaining: 1m 12s
# 266:	learn: 0.3280806	total: 26.3s	remaining: 1m 12s
# 267:	learn: 0.3266633	total: 26.4s	remaining: 1m 12s
# 268:	learn: 0.3258822	total: 26.5s	remaining: 1m 11s
# 269:	learn: 0.3251203	total: 26.6s	remaining: 1m 11s
# 270:	learn: 0.3239852	total: 26.7s	remaining: 1m 11s
# 271:	learn: 0.3233499	total: 26.8s	remaining: 1m 11s
# 272:	learn: 0.3230695	total: 26.9s	remaining: 1m 11s
# 273:	learn: 0.3217738	total: 26.9s	remaining: 1m 11s
# 274:	learn: 0.3209292	total: 27.1s	remaining: 1m 11s
# 275:	learn: 0.3206112	total: 27.2s	remaining: 1m 11s
# 276:	learn: 0.3196980	total: 27.3s	remaining: 1m 11s
# 277:	learn: 0.3188649	total: 27.4s	remaining: 1m 11s
# 278:	learn: 0.3181295	total: 27.5s	remaining: 1m 11s
# 279:	learn: 0.3174163	total: 27.6s	remaining: 1m 11s
# 280:	learn: 0.3169705	total: 27.7s	remaining: 1m 10s
# 281:	learn: 0.3160418	total: 27.8s	remaining: 1m 10s
# 282:	learn: 0.3154955	total: 27.9s	remaining: 1m 10s
# 283:	learn: 0.3140286	total: 28s	remaining: 1m 10s
# 284:	learn: 0.3131797	total: 28.1s	remaining: 1m 10s
# 285:	learn: 0.3121119	total: 28.2s	remaining: 1m 10s
# 286:	learn: 0.3114047	total: 28.3s	remaining: 1m 10s
# 287:	learn: 0.3106044	total: 28.4s	remaining: 1m 10s
# 288:	learn: 0.3096845	total: 28.6s	remaining: 1m 10s
# 289:	learn: 0.3089763	total: 28.7s	remaining: 1m 10s
# 290:	learn: 0.3085097	total: 28.8s	remaining: 1m 10s
# 291:	learn: 0.3082129	total: 28.9s	remaining: 1m 9s
# 292:	learn: 0.3075234	total: 29s	remaining: 1m 9s
# 293:	learn: 0.3066776	total: 29.1s	remaining: 1m 9s
# 294:	learn: 0.3058191	total: 29.2s	remaining: 1m 9s
# 295:	learn: 0.3047398	total: 29.3s	remaining: 1m 9s
# 296:	learn: 0.3041400	total: 29.4s	remaining: 1m 9s
# 297:	learn: 0.3035629	total: 29.5s	remaining: 1m 9s
# 298:	learn: 0.3022825	total: 29.6s	remaining: 1m 9s
# 299:	learn: 0.3017367	total: 29.7s	remaining: 1m 9s
# 300:	learn: 0.3008695	total: 29.8s	remaining: 1m 9s
# 301:	learn: 0.3002285	total: 29.9s	remaining: 1m 9s
# 302:	learn: 0.2996057	total: 30s	remaining: 1m 8s
# 303:	learn: 0.2989541	total: 30.1s	remaining: 1m 8s
# 304:	learn: 0.2983503	total: 30.2s	remaining: 1m 8s
# 305:	learn: 0.2980807	total: 30.3s	remaining: 1m 8s
# 306:	learn: 0.2973199	total: 30.4s	remaining: 1m 8s
# 307:	learn: 0.2963728	total: 30.5s	remaining: 1m 8s
# 308:	learn: 0.2948218	total: 30.6s	remaining: 1m 8s
# 309:	learn: 0.2943661	total: 30.7s	remaining: 1m 8s
# 310:	learn: 0.2936739	total: 30.8s	remaining: 1m 8s
# 311:	learn: 0.2931857	total: 30.9s	remaining: 1m 8s
# 312:	learn: 0.2924061	total: 31s	remaining: 1m 7s
# 313:	learn: 0.2911502	total: 31.1s	remaining: 1m 7s
# 314:	learn: 0.2900617	total: 31.2s	remaining: 1m 7s
# 315:	learn: 0.2886287	total: 31.3s	remaining: 1m 7s
# 316:	learn: 0.2878413	total: 31.4s	remaining: 1m 7s
# 317:	learn: 0.2870751	total: 31.5s	remaining: 1m 7s
# 318:	learn: 0.2859906	total: 31.6s	remaining: 1m 7s
# 319:	learn: 0.2852112	total: 31.7s	remaining: 1m 7s
# 320:	learn: 0.2846709	total: 31.7s	remaining: 1m 7s
# 321:	learn: 0.2838454	total: 31.8s	remaining: 1m 7s
# 322:	learn: 0.2833979	total: 31.9s	remaining: 1m 6s
# 323:	learn: 0.2826478	total: 32s	remaining: 1m 6s
# 324:	learn: 0.2815135	total: 32.1s	remaining: 1m 6s
# 325:	learn: 0.2808914	total: 32.2s	remaining: 1m 6s
# 326:	learn: 0.2803869	total: 32.3s	remaining: 1m 6s
# 327:	learn: 0.2796859	total: 32.4s	remaining: 1m 6s
# 328:	learn: 0.2785508	total: 32.5s	remaining: 1m 6s
# 329:	learn: 0.2774682	total: 32.6s	remaining: 1m 6s
# 330:	learn: 0.2769807	total: 32.7s	remaining: 1m 6s
# 331:	learn: 0.2761731	total: 32.8s	remaining: 1m 6s
# 332:	learn: 0.2752742	total: 32.9s	remaining: 1m 5s
# 333:	learn: 0.2747171	total: 33s	remaining: 1m 5s
# 334:	learn: 0.2737647	total: 33.1s	remaining: 1m 5s
# 335:	learn: 0.2733348	total: 33.2s	remaining: 1m 5s
# 336:	learn: 0.2722449	total: 33.3s	remaining: 1m 5s
# 337:	learn: 0.2717213	total: 33.4s	remaining: 1m 5s
# 338:	learn: 0.2709513	total: 33.5s	remaining: 1m 5s
# 339:	learn: 0.2698344	total: 33.6s	remaining: 1m 5s
# 340:	learn: 0.2692036	total: 33.7s	remaining: 1m 5s
# 341:	learn: 0.2688169	total: 33.8s	remaining: 1m 4s
# 342:	learn: 0.2682338	total: 33.9s	remaining: 1m 4s
# 343:	learn: 0.2678158	total: 33.9s	remaining: 1m 4s
# 344:	learn: 0.2672561	total: 34s	remaining: 1m 4s
# 345:	learn: 0.2664203	total: 34.1s	remaining: 1m 4s
# 346:	learn: 0.2655699	total: 34.2s	remaining: 1m 4s
# 347:	learn: 0.2643534	total: 34.3s	remaining: 1m 4s
# 348:	learn: 0.2636773	total: 34.4s	remaining: 1m 4s
# 349:	learn: 0.2632550	total: 34.5s	remaining: 1m 4s
# 350:	learn: 0.2629931	total: 34.6s	remaining: 1m 4s
# 351:	learn: 0.2626087	total: 34.7s	remaining: 1m 3s
# 352:	learn: 0.2619136	total: 34.8s	remaining: 1m 3s
# 353:	learn: 0.2613633	total: 34.9s	remaining: 1m 3s
# 354:	learn: 0.2609056	total: 35s	remaining: 1m 3s
# 355:	learn: 0.2600875	total: 35.1s	remaining: 1m 3s
# 356:	learn: 0.2593924	total: 35.2s	remaining: 1m 3s
# 357:	learn: 0.2589486	total: 35.3s	remaining: 1m 3s
# 358:	learn: 0.2583547	total: 35.4s	remaining: 1m 3s
# 359:	learn: 0.2567817	total: 35.5s	remaining: 1m 3s
# 360:	learn: 0.2561186	total: 35.6s	remaining: 1m 2s
# 361:	learn: 0.2554542	total: 35.7s	remaining: 1m 2s
# 362:	learn: 0.2547971	total: 35.7s	remaining: 1m 2s
# 363:	learn: 0.2540155	total: 35.8s	remaining: 1m 2s
# 364:	learn: 0.2534061	total: 35.9s	remaining: 1m 2s
# 365:	learn: 0.2528020	total: 36s	remaining: 1m 2s
# 366:	learn: 0.2523068	total: 36.1s	remaining: 1m 2s
# 367:	learn: 0.2516807	total: 36.2s	remaining: 1m 2s
# 368:	learn: 0.2512186	total: 36.3s	remaining: 1m 2s
# 369:	learn: 0.2507264	total: 36.4s	remaining: 1m 1s
# 370:	learn: 0.2505881	total: 36.5s	remaining: 1m 1s
# 371:	learn: 0.2499437	total: 36.6s	remaining: 1m 1s
# 372:	learn: 0.2490121	total: 36.7s	remaining: 1m 1s
# 373:	learn: 0.2483451	total: 36.8s	remaining: 1m 1s
# 374:	learn: 0.2480651	total: 36.9s	remaining: 1m 1s
# 375:	learn: 0.2477277	total: 37s	remaining: 1m 1s
# 376:	learn: 0.2471239	total: 37.1s	remaining: 1m 1s
# 377:	learn: 0.2463938	total: 37.2s	remaining: 1m 1s
# 378:	learn: 0.2460849	total: 37.3s	remaining: 1m 1s
# 379:	learn: 0.2455555	total: 37.4s	remaining: 1m
# 380:	learn: 0.2440659	total: 37.5s	remaining: 1m
# 381:	learn: 0.2436000	total: 37.6s	remaining: 1m
# 382:	learn: 0.2423406	total: 37.7s	remaining: 1m
# 383:	learn: 0.2417852	total: 37.8s	remaining: 1m
# 384:	learn: 0.2410676	total: 37.9s	remaining: 1m
# 385:	learn: 0.2407096	total: 38s	remaining: 1m
# 386:	learn: 0.2400082	total: 38.1s	remaining: 1m
# 387:	learn: 0.2394138	total: 38.2s	remaining: 1m
# 388:	learn: 0.2386592	total: 38.3s	remaining: 1m
# 389:	learn: 0.2376378	total: 38.4s	remaining: 1m
# 390:	learn: 0.2370275	total: 38.5s	remaining: 59.9s
# 391:	learn: 0.2367168	total: 38.6s	remaining: 59.8s
# 392:	learn: 0.2364535	total: 38.7s	remaining: 59.7s
# 393:	learn: 0.2358640	total: 38.8s	remaining: 59.6s
# 394:	learn: 0.2349919	total: 38.9s	remaining: 59.5s
# 395:	learn: 0.2342717	total: 39s	remaining: 59.4s
# 396:	learn: 0.2340504	total: 39.1s	remaining: 59.3s
# 397:	learn: 0.2334255	total: 39.2s	remaining: 59.2s
# 398:	learn: 0.2326468	total: 39.3s	remaining: 59.1s
# 399:	learn: 0.2321355	total: 39.4s	remaining: 59.1s
# 400:	learn: 0.2310532	total: 39.5s	remaining: 59s
# 401:	learn: 0.2308164	total: 39.6s	remaining: 58.9s
# 402:	learn: 0.2303646	total: 39.7s	remaining: 58.8s
# 403:	learn: 0.2298477	total: 39.8s	remaining: 58.7s
# 404:	learn: 0.2292143	total: 39.9s	remaining: 58.6s
# 405:	learn: 0.2284904	total: 40s	remaining: 58.5s
# 406:	learn: 0.2281639	total: 40.1s	remaining: 58.4s
# 407:	learn: 0.2274034	total: 40.2s	remaining: 58.3s
# 408:	learn: 0.2269692	total: 40.3s	remaining: 58.2s
# 409:	learn: 0.2263610	total: 40.4s	remaining: 58.1s
# 410:	learn: 0.2255104	total: 40.5s	remaining: 58s
# 411:	learn: 0.2249921	total: 40.6s	remaining: 57.9s
# 412:	learn: 0.2247172	total: 40.7s	remaining: 57.8s
# 413:	learn: 0.2240797	total: 40.8s	remaining: 57.7s
# 414:	learn: 0.2233681	total: 40.9s	remaining: 57.6s
# 415:	learn: 0.2226782	total: 41s	remaining: 57.5s
# 416:	learn: 0.2220546	total: 41.1s	remaining: 57.4s
# 417:	learn: 0.2214634	total: 41.2s	remaining: 57.3s
# 418:	learn: 0.2210536	total: 41.3s	remaining: 57.2s
# 419:	learn: 0.2202660	total: 41.4s	remaining: 57.1s
# 420:	learn: 0.2196961	total: 41.5s	remaining: 57s
# 421:	learn: 0.2195315	total: 41.6s	remaining: 56.9s
# 422:	learn: 0.2191115	total: 41.7s	remaining: 56.8s
# 423:	learn: 0.2188363	total: 41.8s	remaining: 56.7s
# 424:	learn: 0.2184334	total: 41.9s	remaining: 56.6s
# 425:	learn: 0.2180612	total: 42s	remaining: 56.5s
# 426:	learn: 0.2177364	total: 42.1s	remaining: 56.4s
# 427:	learn: 0.2172265	total: 42.2s	remaining: 56.3s
# 428:	learn: 0.2167727	total: 42.3s	remaining: 56.2s
# 429:	learn: 0.2162030	total: 42.4s	remaining: 56.1s
# 430:	learn: 0.2158600	total: 42.5s	remaining: 56.1s
# 431:	learn: 0.2155373	total: 42.6s	remaining: 56s
# 432:	learn: 0.2149011	total: 42.7s	remaining: 55.9s
# 433:	learn: 0.2146482	total: 42.8s	remaining: 55.8s
# 434:	learn: 0.2139243	total: 42.9s	remaining: 55.7s
# 435:	learn: 0.2132351	total: 43s	remaining: 55.6s
# 436:	learn: 0.2129496	total: 43.1s	remaining: 55.5s
# 437:	learn: 0.2122618	total: 43.2s	remaining: 55.4s
# 438:	learn: 0.2116705	total: 43.3s	remaining: 55.3s
# 439:	learn: 0.2113075	total: 43.4s	remaining: 55.2s
# 440:	learn: 0.2108351	total: 43.4s	remaining: 55.1s
# 441:	learn: 0.2105184	total: 43.5s	remaining: 55s
# 442:	learn: 0.2100376	total: 43.6s	remaining: 54.9s
# 443:	learn: 0.2095882	total: 43.7s	remaining: 54.8s
# 444:	learn: 0.2087559	total: 43.8s	remaining: 54.7s
# 445:	learn: 0.2083004	total: 43.9s	remaining: 54.6s
# 446:	learn: 0.2079327	total: 44s	remaining: 54.5s
# 447:	learn: 0.2070865	total: 44.1s	remaining: 54.3s
# 448:	learn: 0.2061660	total: 44.2s	remaining: 54.2s
# 449:	learn: 0.2059615	total: 44.3s	remaining: 54.1s
# 450:	learn: 0.2053634	total: 44.4s	remaining: 54.1s
# 451:	learn: 0.2048413	total: 44.5s	remaining: 54s
# 452:	learn: 0.2042176	total: 44.6s	remaining: 53.9s
# 453:	learn: 0.2040355	total: 44.7s	remaining: 53.8s
# 454:	learn: 0.2037287	total: 44.8s	remaining: 53.7s
# 455:	learn: 0.2033760	total: 44.9s	remaining: 53.6s
# 456:	learn: 0.2029568	total: 45s	remaining: 53.5s
# 457:	learn: 0.2026559	total: 45.1s	remaining: 53.4s
# 458:	learn: 0.2021687	total: 45.2s	remaining: 53.3s
# 459:	learn: 0.2017268	total: 45.3s	remaining: 53.2s
# 460:	learn: 0.2013192	total: 45.4s	remaining: 53.1s
# 461:	learn: 0.2008177	total: 45.5s	remaining: 53s
# 462:	learn: 0.2002577	total: 45.6s	remaining: 52.9s
# 463:	learn: 0.1999902	total: 45.7s	remaining: 52.8s
# 464:	learn: 0.1997230	total: 45.8s	remaining: 52.7s
# 465:	learn: 0.1991917	total: 45.9s	remaining: 52.6s
# 466:	learn: 0.1987215	total: 46s	remaining: 52.4s
# 467:	learn: 0.1981636	total: 46s	remaining: 52.3s
# 468:	learn: 0.1978490	total: 46.1s	remaining: 52.2s
# 469:	learn: 0.1976167	total: 46.2s	remaining: 52.1s
# 470:	learn: 0.1972904	total: 46.3s	remaining: 52s
# 471:	learn: 0.1966084	total: 46.4s	remaining: 51.9s
# 472:	learn: 0.1964032	total: 46.5s	remaining: 51.8s
# 473:	learn: 0.1959802	total: 46.6s	remaining: 51.7s
# 474:	learn: 0.1955650	total: 46.7s	remaining: 51.6s
# 475:	learn: 0.1952706	total: 46.8s	remaining: 51.5s
# 476:	learn: 0.1948424	total: 46.9s	remaining: 51.4s
# 477:	learn: 0.1943397	total: 47s	remaining: 51.3s
# 478:	learn: 0.1939690	total: 47.1s	remaining: 51.2s
# 479:	learn: 0.1934279	total: 47.2s	remaining: 51.1s
# 480:	learn: 0.1931572	total: 47.3s	remaining: 51s
# 481:	learn: 0.1923695	total: 47.4s	remaining: 50.9s
# 482:	learn: 0.1920834	total: 47.5s	remaining: 50.8s
# 483:	learn: 0.1913096	total: 47.6s	remaining: 50.7s
# 484:	learn: 0.1908574	total: 47.7s	remaining: 50.6s
# 485:	learn: 0.1905448	total: 47.8s	remaining: 50.5s
# 486:	learn: 0.1899491	total: 47.9s	remaining: 50.4s
# 487:	learn: 0.1896880	total: 48s	remaining: 50.3s
# 488:	learn: 0.1891551	total: 48s	remaining: 50.2s
# 489:	learn: 0.1889774	total: 48.1s	remaining: 50.1s
# 490:	learn: 0.1884142	total: 48.2s	remaining: 50s
# 491:	learn: 0.1881842	total: 48.3s	remaining: 49.9s
# 492:	learn: 0.1878726	total: 48.4s	remaining: 49.8s
# 493:	learn: 0.1875589	total: 48.5s	remaining: 49.7s
# 494:	learn: 0.1869764	total: 48.6s	remaining: 49.6s
# 495:	learn: 0.1866182	total: 48.7s	remaining: 49.5s
# 496:	learn: 0.1861949	total: 48.8s	remaining: 49.4s
# 497:	learn: 0.1857504	total: 48.9s	remaining: 49.3s
# 498:	learn: 0.1851997	total: 49s	remaining: 49.2s
# 499:	learn: 0.1849145	total: 49.1s	remaining: 49.1s
# 500:	learn: 0.1845316	total: 49.2s	remaining: 49s
# 501:	learn: 0.1842854	total: 49.3s	remaining: 48.9s
# 502:	learn: 0.1839596	total: 49.4s	remaining: 48.8s
# 503:	learn: 0.1835003	total: 49.5s	remaining: 48.7s
# 504:	learn: 0.1830886	total: 49.6s	remaining: 48.6s
# 505:	learn: 0.1826063	total: 49.7s	remaining: 48.5s
# 506:	learn: 0.1822638	total: 49.8s	remaining: 48.4s
# 507:	learn: 0.1819047	total: 49.9s	remaining: 48.3s
# 508:	learn: 0.1816719	total: 50s	remaining: 48.2s
# 509:	learn: 0.1814400	total: 50.1s	remaining: 48.1s
# 510:	learn: 0.1813039	total: 50.2s	remaining: 48s
# 511:	learn: 0.1811309	total: 50.3s	remaining: 47.9s
# 512:	learn: 0.1808675	total: 50.4s	remaining: 47.8s
# 513:	learn: 0.1806818	total: 50.5s	remaining: 47.7s
# 514:	learn: 0.1803522	total: 50.6s	remaining: 47.6s
# 515:	learn: 0.1801250	total: 50.7s	remaining: 47.5s
# 516:	learn: 0.1798096	total: 50.8s	remaining: 47.4s
# 517:	learn: 0.1793975	total: 50.9s	remaining: 47.3s
# 518:	learn: 0.1790957	total: 51s	remaining: 47.2s
# 519:	learn: 0.1788076	total: 51.1s	remaining: 47.1s
# 520:	learn: 0.1785869	total: 51.1s	remaining: 47s
# 521:	learn: 0.1781985	total: 51.2s	remaining: 46.9s
# 522:	learn: 0.1777917	total: 51.3s	remaining: 46.8s
# 523:	learn: 0.1775155	total: 51.4s	remaining: 46.7s
# 524:	learn: 0.1772128	total: 51.5s	remaining: 46.6s
# 525:	learn: 0.1765368	total: 51.6s	remaining: 46.5s
# 526:	learn: 0.1758796	total: 51.7s	remaining: 46.4s
# 527:	learn: 0.1753123	total: 51.8s	remaining: 46.3s
# 528:	learn: 0.1749693	total: 51.9s	remaining: 46.2s
# 529:	learn: 0.1744774	total: 52s	remaining: 46.1s
# 530:	learn: 0.1740852	total: 52.1s	remaining: 46s
# 531:	learn: 0.1736921	total: 52.2s	remaining: 45.9s
# 532:	learn: 0.1735193	total: 52.3s	remaining: 45.8s
# 533:	learn: 0.1732525	total: 52.4s	remaining: 45.7s
# 534:	learn: 0.1726712	total: 52.5s	remaining: 45.6s
# 535:	learn: 0.1722734	total: 52.6s	remaining: 45.5s
# 536:	learn: 0.1719869	total: 52.7s	remaining: 45.4s
# 537:	learn: 0.1718276	total: 52.8s	remaining: 45.3s
# 538:	learn: 0.1716183	total: 52.9s	remaining: 45.2s
# 539:	learn: 0.1712787	total: 53s	remaining: 45.1s
# 540:	learn: 0.1709629	total: 53.1s	remaining: 45s
# 541:	learn: 0.1707790	total: 53.2s	remaining: 44.9s
# 542:	learn: 0.1705765	total: 53.3s	remaining: 44.8s
# 543:	learn: 0.1703041	total: 53.4s	remaining: 44.7s
# 544:	learn: 0.1700369	total: 53.5s	remaining: 44.7s
# 545:	learn: 0.1694772	total: 53.6s	remaining: 44.6s
# 546:	learn: 0.1691478	total: 53.7s	remaining: 44.5s
# 547:	learn: 0.1686445	total: 53.8s	remaining: 44.4s
# 548:	learn: 0.1682095	total: 53.9s	remaining: 44.3s
# 549:	learn: 0.1679752	total: 54s	remaining: 44.2s
# 550:	learn: 0.1677830	total: 54.1s	remaining: 44.1s
# 551:	learn: 0.1675233	total: 54.2s	remaining: 44s
# 552:	learn: 0.1672568	total: 54.3s	remaining: 43.9s
# 553:	learn: 0.1665291	total: 54.4s	remaining: 43.8s
# 554:	learn: 0.1660547	total: 54.5s	remaining: 43.7s
# 555:	learn: 0.1657929	total: 54.6s	remaining: 43.6s
# 556:	learn: 0.1653417	total: 54.7s	remaining: 43.5s
# 557:	learn: 0.1649871	total: 54.8s	remaining: 43.4s
# 558:	learn: 0.1647481	total: 54.9s	remaining: 43.3s
# 559:	learn: 0.1641588	total: 55s	remaining: 43.2s
# 560:	learn: 0.1638381	total: 55.1s	remaining: 43.1s
# 561:	learn: 0.1635380	total: 55.2s	remaining: 43s
# 562:	learn: 0.1631384	total: 55.2s	remaining: 42.9s
# 563:	learn: 0.1627630	total: 55.3s	remaining: 42.8s
# 564:	learn: 0.1624822	total: 55.4s	remaining: 42.7s
# 565:	learn: 0.1622669	total: 55.5s	remaining: 42.6s
# 566:	learn: 0.1616372	total: 55.6s	remaining: 42.5s
# 567:	learn: 0.1612764	total: 55.7s	remaining: 42.4s
# 568:	learn: 0.1607834	total: 55.8s	remaining: 42.3s
# 569:	learn: 0.1606230	total: 55.9s	remaining: 42.2s
# 570:	learn: 0.1604813	total: 56s	remaining: 42.1s
# 571:	learn: 0.1602583	total: 56.1s	remaining: 42s
# 572:	learn: 0.1600473	total: 56.2s	remaining: 41.9s
# 573:	learn: 0.1595743	total: 56.3s	remaining: 41.8s
# 574:	learn: 0.1592151	total: 56.4s	remaining: 41.7s
# 575:	learn: 0.1590115	total: 56.5s	remaining: 41.6s
# 576:	learn: 0.1587791	total: 56.6s	remaining: 41.5s
# 577:	learn: 0.1584534	total: 56.7s	remaining: 41.4s
# 578:	learn: 0.1582970	total: 56.8s	remaining: 41.3s
# 579:	learn: 0.1576881	total: 56.9s	remaining: 41.2s
# 580:	learn: 0.1571774	total: 57s	remaining: 41.1s
# 581:	learn: 0.1569943	total: 57.1s	remaining: 41s
# 582:	learn: 0.1568100	total: 57.2s	remaining: 40.9s
# 583:	learn: 0.1566015	total: 57.3s	remaining: 40.8s
# 584:	learn: 0.1563807	total: 57.4s	remaining: 40.7s
# 585:	learn: 0.1559512	total: 57.5s	remaining: 40.7s
# 586:	learn: 0.1556526	total: 57.6s	remaining: 40.6s
# 587:	learn: 0.1555016	total: 57.7s	remaining: 40.5s
# 588:	learn: 0.1550223	total: 57.8s	remaining: 40.4s
# 589:	learn: 0.1547368	total: 57.9s	remaining: 40.3s
# 590:	learn: 0.1543140	total: 58s	remaining: 40.2s
# 591:	learn: 0.1541024	total: 58.1s	remaining: 40.1s
# 592:	learn: 0.1539172	total: 58.2s	remaining: 40s
# 593:	learn: 0.1536941	total: 58.3s	remaining: 39.9s
# 594:	learn: 0.1535475	total: 58.4s	remaining: 39.8s
# 595:	learn: 0.1533895	total: 58.5s	remaining: 39.7s
# 596:	learn: 0.1532107	total: 58.6s	remaining: 39.6s
# 597:	learn: 0.1529921	total: 58.7s	remaining: 39.5s
# 598:	learn: 0.1528657	total: 58.8s	remaining: 39.4s
# 599:	learn: 0.1526926	total: 58.9s	remaining: 39.3s
# 600:	learn: 0.1524073	total: 59s	remaining: 39.2s
# 601:	learn: 0.1522422	total: 59.1s	remaining: 39.1s
# 602:	learn: 0.1520133	total: 59.2s	remaining: 39s
# 603:	learn: 0.1516531	total: 59.3s	remaining: 38.9s
# 604:	learn: 0.1514663	total: 59.4s	remaining: 38.8s
# 605:	learn: 0.1512302	total: 59.5s	remaining: 38.7s
# 606:	learn: 0.1509630	total: 59.6s	remaining: 38.6s
# 607:	learn: 0.1508616	total: 59.7s	remaining: 38.5s
# 608:	learn: 0.1506727	total: 59.8s	remaining: 38.4s
# 609:	learn: 0.1502757	total: 59.9s	remaining: 38.3s
# 610:	learn: 0.1500668	total: 1m	remaining: 38.2s
# 611:	learn: 0.1498458	total: 1m	remaining: 38.1s
# 612:	learn: 0.1494958	total: 1m	remaining: 38s
# 613:	learn: 0.1492250	total: 1m	remaining: 37.9s
# 614:	learn: 0.1488258	total: 1m	remaining: 37.8s
# 615:	learn: 0.1486827	total: 1m	remaining: 37.7s
# 616:	learn: 0.1484912	total: 1m	remaining: 37.6s
# 617:	learn: 0.1482889	total: 1m	remaining: 37.5s
# 618:	learn: 0.1480788	total: 1m	remaining: 37.4s
# 619:	learn: 0.1478281	total: 1m	remaining: 37.3s
# 620:	learn: 0.1476769	total: 1m 1s	remaining: 37.2s
# 621:	learn: 0.1475203	total: 1m 1s	remaining: 37.1s
# 622:	learn: 0.1473827	total: 1m 1s	remaining: 37s
# 623:	learn: 0.1472228	total: 1m 1s	remaining: 36.9s
# 624:	learn: 0.1470270	total: 1m 1s	remaining: 36.8s
# 625:	learn: 0.1468947	total: 1m 1s	remaining: 36.8s
# 626:	learn: 0.1466986	total: 1m 1s	remaining: 36.7s
# 627:	learn: 0.1463168	total: 1m 1s	remaining: 36.6s
# 628:	learn: 0.1458647	total: 1m 1s	remaining: 36.5s
# 629:	learn: 0.1455609	total: 1m 1s	remaining: 36.4s
# 630:	learn: 0.1452842	total: 1m 2s	remaining: 36.3s
# 631:	learn: 0.1448896	total: 1m 2s	remaining: 36.2s
# 632:	learn: 0.1445573	total: 1m 2s	remaining: 36.1s
# 633:	learn: 0.1443998	total: 1m 2s	remaining: 36s
# 634:	learn: 0.1440564	total: 1m 2s	remaining: 35.9s
# 635:	learn: 0.1436131	total: 1m 2s	remaining: 35.8s
# 636:	learn: 0.1433389	total: 1m 2s	remaining: 35.7s
# 637:	learn: 0.1430881	total: 1m 2s	remaining: 35.6s
# 638:	learn: 0.1429004	total: 1m 2s	remaining: 35.5s
# 639:	learn: 0.1425549	total: 1m 2s	remaining: 35.4s
# 640:	learn: 0.1421536	total: 1m 2s	remaining: 35.3s
# 641:	learn: 0.1420005	total: 1m 3s	remaining: 35.1s
# 642:	learn: 0.1418731	total: 1m 3s	remaining: 35s
# 643:	learn: 0.1414709	total: 1m 3s	remaining: 34.9s
# 644:	learn: 0.1408630	total: 1m 3s	remaining: 34.8s
# 645:	learn: 0.1407260	total: 1m 3s	remaining: 34.7s
# 646:	learn: 0.1403812	total: 1m 3s	remaining: 34.6s
# 647:	learn: 0.1399471	total: 1m 3s	remaining: 34.5s
# 648:	learn: 0.1395905	total: 1m 3s	remaining: 34.4s
# 649:	learn: 0.1393997	total: 1m 3s	remaining: 34.3s
# 650:	learn: 0.1391068	total: 1m 3s	remaining: 34.2s
# 651:	learn: 0.1387597	total: 1m 3s	remaining: 34.1s
# 652:	learn: 0.1382547	total: 1m 4s	remaining: 34s
# 653:	learn: 0.1380463	total: 1m 4s	remaining: 33.9s
# 654:	learn: 0.1377873	total: 1m 4s	remaining: 33.8s
# 655:	learn: 0.1376057	total: 1m 4s	remaining: 33.7s
# 656:	learn: 0.1373399	total: 1m 4s	remaining: 33.6s
# 657:	learn: 0.1367684	total: 1m 4s	remaining: 33.5s
# 658:	learn: 0.1365407	total: 1m 4s	remaining: 33.4s
# 659:	learn: 0.1364009	total: 1m 4s	remaining: 33.3s
# 660:	learn: 0.1361591	total: 1m 4s	remaining: 33.2s
# 661:	learn: 0.1357526	total: 1m 4s	remaining: 33.1s
# 662:	learn: 0.1353589	total: 1m 4s	remaining: 33s
# 663:	learn: 0.1350645	total: 1m 5s	remaining: 32.9s
# 664:	learn: 0.1346169	total: 1m 5s	remaining: 32.8s
# 665:	learn: 0.1344242	total: 1m 5s	remaining: 32.7s
# 666:	learn: 0.1342269	total: 1m 5s	remaining: 32.6s
# 667:	learn: 0.1341357	total: 1m 5s	remaining: 32.5s
# 668:	learn: 0.1340249	total: 1m 5s	remaining: 32.4s
# 669:	learn: 0.1337907	total: 1m 5s	remaining: 32.3s
# 670:	learn: 0.1333305	total: 1m 5s	remaining: 32.2s
# 671:	learn: 0.1332196	total: 1m 5s	remaining: 32.1s
# 672:	learn: 0.1330096	total: 1m 5s	remaining: 32s
# 673:	learn: 0.1326920	total: 1m 6s	remaining: 31.9s
# 674:	learn: 0.1325059	total: 1m 6s	remaining: 31.8s
# 675:	learn: 0.1323921	total: 1m 6s	remaining: 31.7s
# 676:	learn: 0.1320939	total: 1m 6s	remaining: 31.6s
# 677:	learn: 0.1319385	total: 1m 6s	remaining: 31.5s
# 678:	learn: 0.1315983	total: 1m 6s	remaining: 31.4s
# 679:	learn: 0.1314992	total: 1m 6s	remaining: 31.3s
# 680:	learn: 0.1312893	total: 1m 6s	remaining: 31.2s
# 681:	learn: 0.1310431	total: 1m 6s	remaining: 31.1s
# 682:	learn: 0.1309481	total: 1m 6s	remaining: 31s
# 683:	learn: 0.1306262	total: 1m 6s	remaining: 30.9s
# 684:	learn: 0.1305400	total: 1m 7s	remaining: 30.9s
# 685:	learn: 0.1304086	total: 1m 7s	remaining: 30.8s
# 686:	learn: 0.1302645	total: 1m 7s	remaining: 30.7s
# 687:	learn: 0.1300340	total: 1m 7s	remaining: 30.6s
# 688:	learn: 0.1295517	total: 1m 7s	remaining: 30.5s
# 689:	learn: 0.1294237	total: 1m 7s	remaining: 30.4s
# 690:	learn: 0.1292695	total: 1m 7s	remaining: 30.3s
# 691:	learn: 0.1291669	total: 1m 7s	remaining: 30.2s
# 692:	learn: 0.1287847	total: 1m 7s	remaining: 30.1s
# 693:	learn: 0.1286716	total: 1m 7s	remaining: 30s
# 694:	learn: 0.1283348	total: 1m 8s	remaining: 29.9s
# 695:	learn: 0.1281121	total: 1m 8s	remaining: 29.8s
# 696:	learn: 0.1278896	total: 1m 8s	remaining: 29.7s
# 697:	learn: 0.1275912	total: 1m 8s	remaining: 29.6s
# 698:	learn: 0.1274671	total: 1m 8s	remaining: 29.5s
# 699:	learn: 0.1269209	total: 1m 8s	remaining: 29.4s
# 700:	learn: 0.1266120	total: 1m 8s	remaining: 29.3s
# 701:	learn: 0.1262247	total: 1m 8s	remaining: 29.2s
# 702:	learn: 0.1259544	total: 1m 8s	remaining: 29.1s
# 703:	learn: 0.1256526	total: 1m 8s	remaining: 29s
# 704:	learn: 0.1254236	total: 1m 8s	remaining: 28.9s
# 705:	learn: 0.1253324	total: 1m 9s	remaining: 28.8s
# 706:	learn: 0.1250747	total: 1m 9s	remaining: 28.7s
# 707:	learn: 0.1249696	total: 1m 9s	remaining: 28.6s
# 708:	learn: 0.1247429	total: 1m 9s	remaining: 28.5s
# 709:	learn: 0.1244422	total: 1m 9s	remaining: 28.4s
# 710:	learn: 0.1243493	total: 1m 9s	remaining: 28.3s
# 711:	learn: 0.1242185	total: 1m 9s	remaining: 28.2s
# 712:	learn: 0.1239067	total: 1m 9s	remaining: 28.1s
# 713:	learn: 0.1236945	total: 1m 9s	remaining: 28s
# 714:	learn: 0.1235601	total: 1m 10s	remaining: 27.9s
# 715:	learn: 0.1233077	total: 1m 10s	remaining: 27.8s
# 716:	learn: 0.1231863	total: 1m 10s	remaining: 27.7s
# 717:	learn: 0.1229356	total: 1m 10s	remaining: 27.6s
# 718:	learn: 0.1225816	total: 1m 10s	remaining: 27.5s
# 719:	learn: 0.1222198	total: 1m 10s	remaining: 27.4s
# 720:	learn: 0.1219356	total: 1m 10s	remaining: 27.3s
# 721:	learn: 0.1216746	total: 1m 10s	remaining: 27.2s
# 722:	learn: 0.1213923	total: 1m 10s	remaining: 27.1s
# 723:	learn: 0.1212470	total: 1m 10s	remaining: 27s
# 724:	learn: 0.1211664	total: 1m 10s	remaining: 26.9s
# 725:	learn: 0.1209987	total: 1m 11s	remaining: 26.8s
# 726:	learn: 0.1207403	total: 1m 11s	remaining: 26.7s
# 727:	learn: 0.1204405	total: 1m 11s	remaining: 26.6s
# 728:	learn: 0.1202158	total: 1m 11s	remaining: 26.5s
# 729:	learn: 0.1197731	total: 1m 11s	remaining: 26.4s
# 730:	learn: 0.1196830	total: 1m 11s	remaining: 26.3s
# 731:	learn: 0.1193814	total: 1m 11s	remaining: 26.2s
# 732:	learn: 0.1190703	total: 1m 11s	remaining: 26.1s
# 733:	learn: 0.1190280	total: 1m 11s	remaining: 26.1s
# 734:	learn: 0.1188828	total: 1m 11s	remaining: 26s
# 735:	learn: 0.1186747	total: 1m 12s	remaining: 25.9s
# 736:	learn: 0.1184393	total: 1m 12s	remaining: 25.8s
# 737:	learn: 0.1180355	total: 1m 12s	remaining: 25.7s
# 738:	learn: 0.1178500	total: 1m 12s	remaining: 25.6s
# 739:	learn: 0.1177067	total: 1m 12s	remaining: 25.5s
# 740:	learn: 0.1174739	total: 1m 12s	remaining: 25.4s
# 741:	learn: 0.1173663	total: 1m 12s	remaining: 25.3s
# 742:	learn: 0.1172721	total: 1m 12s	remaining: 25.2s
# 743:	learn: 0.1171874	total: 1m 12s	remaining: 25.1s
# 744:	learn: 0.1169549	total: 1m 12s	remaining: 25s
# 745:	learn: 0.1165532	total: 1m 13s	remaining: 24.9s
# 746:	learn: 0.1164773	total: 1m 13s	remaining: 24.8s
# 747:	learn: 0.1163394	total: 1m 13s	remaining: 24.7s
# 748:	learn: 0.1162046	total: 1m 13s	remaining: 24.6s
# 749:	learn: 0.1159693	total: 1m 13s	remaining: 24.5s
# 750:	learn: 0.1156736	total: 1m 13s	remaining: 24.4s
# 751:	learn: 0.1154758	total: 1m 13s	remaining: 24.3s
# 752:	learn: 0.1152818	total: 1m 13s	remaining: 24.2s
# 753:	learn: 0.1150098	total: 1m 13s	remaining: 24.1s
# 754:	learn: 0.1146822	total: 1m 13s	remaining: 24s
# 755:	learn: 0.1146062	total: 1m 13s	remaining: 23.9s
# 756:	learn: 0.1142871	total: 1m 14s	remaining: 23.8s
# 757:	learn: 0.1141652	total: 1m 14s	remaining: 23.7s
# 758:	learn: 0.1138800	total: 1m 14s	remaining: 23.6s
# 759:	learn: 0.1137180	total: 1m 14s	remaining: 23.5s
# 760:	learn: 0.1135435	total: 1m 14s	remaining: 23.4s
# 761:	learn: 0.1133948	total: 1m 14s	remaining: 23.3s
# 762:	learn: 0.1131884	total: 1m 14s	remaining: 23.2s
# 763:	learn: 0.1130630	total: 1m 14s	remaining: 23.1s
# 764:	learn: 0.1129455	total: 1m 14s	remaining: 23s
# 765:	learn: 0.1128016	total: 1m 14s	remaining: 22.9s
# 766:	learn: 0.1126673	total: 1m 15s	remaining: 22.8s
# 767:	learn: 0.1125714	total: 1m 15s	remaining: 22.7s
# 768:	learn: 0.1124474	total: 1m 15s	remaining: 22.6s
# 769:	learn: 0.1123573	total: 1m 15s	remaining: 22.5s
# 770:	learn: 0.1122317	total: 1m 15s	remaining: 22.4s
# 771:	learn: 0.1121067	total: 1m 15s	remaining: 22.3s
# 772:	learn: 0.1118638	total: 1m 15s	remaining: 22.2s
# 773:	learn: 0.1116651	total: 1m 15s	remaining: 22.1s
# 774:	learn: 0.1114982	total: 1m 15s	remaining: 22s
# 775:	learn: 0.1112240	total: 1m 15s	remaining: 21.9s
# 776:	learn: 0.1110256	total: 1m 16s	remaining: 21.8s
# 777:	learn: 0.1108406	total: 1m 16s	remaining: 21.7s
# 778:	learn: 0.1107334	total: 1m 16s	remaining: 21.6s
# 779:	learn: 0.1105946	total: 1m 16s	remaining: 21.5s
# 780:	learn: 0.1105160	total: 1m 16s	remaining: 21.4s
# 781:	learn: 0.1104316	total: 1m 16s	remaining: 21.3s
# 782:	learn: 0.1103418	total: 1m 16s	remaining: 21.2s
# 783:	learn: 0.1101787	total: 1m 16s	remaining: 21.1s
# 784:	learn: 0.1100465	total: 1m 16s	remaining: 21s
# 785:	learn: 0.1097787	total: 1m 16s	remaining: 20.9s
# 786:	learn: 0.1095132	total: 1m 17s	remaining: 20.8s
# 787:	learn: 0.1091904	total: 1m 17s	remaining: 20.7s
# 788:	learn: 0.1090592	total: 1m 17s	remaining: 20.6s
# 789:	learn: 0.1087600	total: 1m 17s	remaining: 20.5s
# 790:	learn: 0.1086054	total: 1m 17s	remaining: 20.4s
# 791:	learn: 0.1084951	total: 1m 17s	remaining: 20.4s
# 792:	learn: 0.1083405	total: 1m 17s	remaining: 20.3s
# 793:	learn: 0.1081669	total: 1m 17s	remaining: 20.2s
# 794:	learn: 0.1080648	total: 1m 17s	remaining: 20.1s
# 795:	learn: 0.1078527	total: 1m 17s	remaining: 20s
# 796:	learn: 0.1076596	total: 1m 17s	remaining: 19.9s
# 797:	learn: 0.1075924	total: 1m 18s	remaining: 19.8s
# 798:	learn: 0.1074423	total: 1m 18s	remaining: 19.7s
# 799:	learn: 0.1072737	total: 1m 18s	remaining: 19.6s
# 800:	learn: 0.1071587	total: 1m 18s	remaining: 19.5s
# 801:	learn: 0.1069860	total: 1m 18s	remaining: 19.4s
# 802:	learn: 0.1066845	total: 1m 18s	remaining: 19.3s
# 803:	learn: 0.1065285	total: 1m 18s	remaining: 19.2s
# 804:	learn: 0.1063075	total: 1m 18s	remaining: 19.1s
# 805:	learn: 0.1061576	total: 1m 18s	remaining: 19s
# 806:	learn: 0.1060611	total: 1m 18s	remaining: 18.9s
# 807:	learn: 0.1059097	total: 1m 19s	remaining: 18.8s
# 808:	learn: 0.1057958	total: 1m 19s	remaining: 18.7s
# 809:	learn: 0.1056308	total: 1m 19s	remaining: 18.6s
# 810:	learn: 0.1054279	total: 1m 19s	remaining: 18.5s
# 811:	learn: 0.1052489	total: 1m 19s	remaining: 18.4s
# 812:	learn: 0.1049376	total: 1m 19s	remaining: 18.3s
# 813:	learn: 0.1045851	total: 1m 19s	remaining: 18.2s
# 814:	learn: 0.1044162	total: 1m 19s	remaining: 18.1s
# 815:	learn: 0.1043020	total: 1m 19s	remaining: 18s
# 816:	learn: 0.1040174	total: 1m 19s	remaining: 17.9s
# 817:	learn: 0.1039418	total: 1m 20s	remaining: 17.8s
# 818:	learn: 0.1037389	total: 1m 20s	remaining: 17.7s
# 819:	learn: 0.1035333	total: 1m 20s	remaining: 17.6s
# 820:	learn: 0.1033508	total: 1m 20s	remaining: 17.5s
# 821:	learn: 0.1031900	total: 1m 20s	remaining: 17.4s
# 822:	learn: 0.1030739	total: 1m 20s	remaining: 17.3s
# 823:	learn: 0.1029169	total: 1m 20s	remaining: 17.2s
# 824:	learn: 0.1027506	total: 1m 20s	remaining: 17.1s
# 825:	learn: 0.1025482	total: 1m 20s	remaining: 17s
# 826:	learn: 0.1023110	total: 1m 20s	remaining: 16.9s
# 827:	learn: 0.1021581	total: 1m 21s	remaining: 16.8s
# 828:	learn: 0.1020751	total: 1m 21s	remaining: 16.7s
# 829:	learn: 0.1019896	total: 1m 21s	remaining: 16.6s
# 830:	learn: 0.1018462	total: 1m 21s	remaining: 16.5s
# 831:	learn: 0.1017164	total: 1m 21s	remaining: 16.4s
# 832:	learn: 0.1016245	total: 1m 21s	remaining: 16.3s
# 833:	learn: 0.1015342	total: 1m 21s	remaining: 16.2s
# 834:	learn: 0.1013469	total: 1m 21s	remaining: 16.1s
# 835:	learn: 0.1012604	total: 1m 21s	remaining: 16s
# 836:	learn: 0.1009417	total: 1m 21s	remaining: 15.9s
# 837:	learn: 0.1007800	total: 1m 21s	remaining: 15.8s
# 838:	learn: 0.1005269	total: 1m 22s	remaining: 15.7s
# 839:	learn: 0.1003900	total: 1m 22s	remaining: 15.7s
# 840:	learn: 0.1000448	total: 1m 22s	remaining: 15.6s
# 841:	learn: 0.0998520	total: 1m 22s	remaining: 15.5s
# 842:	learn: 0.0996806	total: 1m 22s	remaining: 15.4s
# 843:	learn: 0.0994260	total: 1m 22s	remaining: 15.3s
# 844:	learn: 0.0992899	total: 1m 22s	remaining: 15.2s
# 845:	learn: 0.0990758	total: 1m 22s	remaining: 15.1s
# 846:	learn: 0.0989065	total: 1m 22s	remaining: 15s
# 847:	learn: 0.0987174	total: 1m 22s	remaining: 14.9s
# 848:	learn: 0.0985277	total: 1m 23s	remaining: 14.8s
# 849:	learn: 0.0984488	total: 1m 23s	remaining: 14.7s
# 850:	learn: 0.0982926	total: 1m 23s	remaining: 14.6s
# 851:	learn: 0.0979716	total: 1m 23s	remaining: 14.5s
# 852:	learn: 0.0978295	total: 1m 23s	remaining: 14.4s
# 853:	learn: 0.0977016	total: 1m 23s	remaining: 14.3s
# 854:	learn: 0.0975528	total: 1m 23s	remaining: 14.2s
# 855:	learn: 0.0972549	total: 1m 23s	remaining: 14.1s
# 856:	learn: 0.0971653	total: 1m 23s	remaining: 14s
# 857:	learn: 0.0970567	total: 1m 23s	remaining: 13.9s
# 858:	learn: 0.0969446	total: 1m 23s	remaining: 13.8s
# 859:	learn: 0.0966604	total: 1m 24s	remaining: 13.7s
# 860:	learn: 0.0965539	total: 1m 24s	remaining: 13.6s
# 861:	learn: 0.0962968	total: 1m 24s	remaining: 13.5s
# 862:	learn: 0.0961844	total: 1m 24s	remaining: 13.4s
# 863:	learn: 0.0960597	total: 1m 24s	remaining: 13.3s
# 864:	learn: 0.0959842	total: 1m 24s	remaining: 13.2s
# 865:	learn: 0.0958361	total: 1m 24s	remaining: 13.1s
# 866:	learn: 0.0957835	total: 1m 24s	remaining: 13s
# 867:	learn: 0.0956621	total: 1m 24s	remaining: 12.9s
# 868:	learn: 0.0955695	total: 1m 24s	remaining: 12.8s
# 869:	learn: 0.0954489	total: 1m 25s	remaining: 12.7s
# 870:	learn: 0.0953251	total: 1m 25s	remaining: 12.6s
# 871:	learn: 0.0949749	total: 1m 25s	remaining: 12.5s
# 872:	learn: 0.0949126	total: 1m 25s	remaining: 12.4s
# 873:	learn: 0.0947985	total: 1m 25s	remaining: 12.3s
# 874:	learn: 0.0945093	total: 1m 25s	remaining: 12.2s
# 875:	learn: 0.0943405	total: 1m 25s	remaining: 12.1s
# 876:	learn: 0.0941896	total: 1m 25s	remaining: 12s
# 877:	learn: 0.0939749	total: 1m 25s	remaining: 11.9s
# 878:	learn: 0.0939097	total: 1m 25s	remaining: 11.8s
# 879:	learn: 0.0938072	total: 1m 25s	remaining: 11.7s
# 880:	learn: 0.0936946	total: 1m 26s	remaining: 11.6s
# 881:	learn: 0.0935497	total: 1m 26s	remaining: 11.5s
# 882:	learn: 0.0932536	total: 1m 26s	remaining: 11.4s
# 883:	learn: 0.0931453	total: 1m 26s	remaining: 11.3s
# 884:	learn: 0.0929534	total: 1m 26s	remaining: 11.2s
# 885:	learn: 0.0928513	total: 1m 26s	remaining: 11.1s
# 886:	learn: 0.0926808	total: 1m 26s	remaining: 11s
# 887:	learn: 0.0925777	total: 1m 26s	remaining: 11s
# 888:	learn: 0.0924599	total: 1m 26s	remaining: 10.9s
# 889:	learn: 0.0923060	total: 1m 27s	remaining: 10.8s
# 890:	learn: 0.0921958	total: 1m 27s	remaining: 10.7s
# 891:	learn: 0.0920791	total: 1m 27s	remaining: 10.6s
# 892:	learn: 0.0919757	total: 1m 27s	remaining: 10.5s
# 893:	learn: 0.0918559	total: 1m 27s	remaining: 10.4s
# 894:	learn: 0.0916649	total: 1m 27s	remaining: 10.3s
# 895:	learn: 0.0914830	total: 1m 27s	remaining: 10.2s
# 896:	learn: 0.0913277	total: 1m 27s	remaining: 10.1s
# 897:	learn: 0.0912609	total: 1m 27s	remaining: 9.98s
# 898:	learn: 0.0911838	total: 1m 27s	remaining: 9.88s
# 899:	learn: 0.0910383	total: 1m 28s	remaining: 9.79s
# 900:	learn: 0.0909397	total: 1m 28s	remaining: 9.69s
# 901:	learn: 0.0906779	total: 1m 28s	remaining: 9.59s
# 902:	learn: 0.0905509	total: 1m 28s	remaining: 9.49s
# 903:	learn: 0.0902860	total: 1m 28s	remaining: 9.4s
# 904:	learn: 0.0901897	total: 1m 28s	remaining: 9.3s
# 905:	learn: 0.0900933	total: 1m 28s	remaining: 9.2s
# 906:	learn: 0.0898985	total: 1m 28s	remaining: 9.1s
# 907:	learn: 0.0897959	total: 1m 28s	remaining: 9.01s
# 908:	learn: 0.0896969	total: 1m 28s	remaining: 8.91s
# 909:	learn: 0.0895964	total: 1m 29s	remaining: 8.81s
# 910:	learn: 0.0895311	total: 1m 29s	remaining: 8.71s
# 911:	learn: 0.0893724	total: 1m 29s	remaining: 8.62s
# 912:	learn: 0.0893018	total: 1m 29s	remaining: 8.52s
# 913:	learn: 0.0892202	total: 1m 29s	remaining: 8.42s
# 914:	learn: 0.0890685	total: 1m 29s	remaining: 8.32s
# 915:	learn: 0.0889093	total: 1m 29s	remaining: 8.23s
# 916:	learn: 0.0887801	total: 1m 29s	remaining: 8.13s
# 917:	learn: 0.0886514	total: 1m 29s	remaining: 8.03s
# 918:	learn: 0.0885867	total: 1m 30s	remaining: 7.93s
# 919:	learn: 0.0884153	total: 1m 30s	remaining: 7.84s
# 920:	learn: 0.0883384	total: 1m 30s	remaining: 7.74s
# 921:	learn: 0.0881654	total: 1m 30s	remaining: 7.65s
# 922:	learn: 0.0880464	total: 1m 30s	remaining: 7.55s
# 923:	learn: 0.0879008	total: 1m 30s	remaining: 7.46s
# 924:	learn: 0.0878203	total: 1m 30s	remaining: 7.36s
# 925:	learn: 0.0877236	total: 1m 30s	remaining: 7.26s
# 926:	learn: 0.0874877	total: 1m 30s	remaining: 7.16s
# 927:	learn: 0.0873543	total: 1m 31s	remaining: 7.07s
# 928:	learn: 0.0872738	total: 1m 31s	remaining: 6.97s
# 929:	learn: 0.0872160	total: 1m 31s	remaining: 6.87s
# 930:	learn: 0.0870817	total: 1m 31s	remaining: 6.77s
# 931:	learn: 0.0869828	total: 1m 31s	remaining: 6.67s
# 932:	learn: 0.0868782	total: 1m 31s	remaining: 6.58s
# 933:	learn: 0.0867060	total: 1m 31s	remaining: 6.48s
# 934:	learn: 0.0865804	total: 1m 31s	remaining: 6.38s
# 935:	learn: 0.0865264	total: 1m 31s	remaining: 6.28s
# 936:	learn: 0.0862977	total: 1m 31s	remaining: 6.18s
# 937:	learn: 0.0861684	total: 1m 32s	remaining: 6.09s
# 938:	learn: 0.0861217	total: 1m 32s	remaining: 5.99s
# 939:	learn: 0.0859984	total: 1m 32s	remaining: 5.89s
# 940:	learn: 0.0858925	total: 1m 32s	remaining: 5.79s
# 941:	learn: 0.0858224	total: 1m 32s	remaining: 5.69s
# 942:	learn: 0.0857018	total: 1m 32s	remaining: 5.6s
# 943:	learn: 0.0855646	total: 1m 32s	remaining: 5.5s
# 944:	learn: 0.0853759	total: 1m 32s	remaining: 5.4s
# 945:	learn: 0.0852585	total: 1m 32s	remaining: 5.3s
# 946:	learn: 0.0852172	total: 1m 32s	remaining: 5.2s
# 947:	learn: 0.0851437	total: 1m 33s	remaining: 5.11s
# 948:	learn: 0.0850184	total: 1m 33s	remaining: 5.01s
# 949:	learn: 0.0849330	total: 1m 33s	remaining: 4.91s
# 950:	learn: 0.0847735	total: 1m 33s	remaining: 4.81s
# 951:	learn: 0.0845490	total: 1m 33s	remaining: 4.71s
# 952:	learn: 0.0842545	total: 1m 33s	remaining: 4.62s
# 953:	learn: 0.0841102	total: 1m 33s	remaining: 4.52s
# 954:	learn: 0.0840072	total: 1m 33s	remaining: 4.42s
# 955:	learn: 0.0836980	total: 1m 33s	remaining: 4.32s
# 956:	learn: 0.0836046	total: 1m 33s	remaining: 4.22s
# 957:	learn: 0.0833809	total: 1m 34s	remaining: 4.12s
# 958:	learn: 0.0832255	total: 1m 34s	remaining: 4.03s
# 959:	learn: 0.0831053	total: 1m 34s	remaining: 3.93s
# 960:	learn: 0.0829285	total: 1m 34s	remaining: 3.83s
# 961:	learn: 0.0828295	total: 1m 34s	remaining: 3.73s
# 962:	learn: 0.0827449	total: 1m 34s	remaining: 3.63s
# 963:	learn: 0.0826309	total: 1m 34s	remaining: 3.54s
# 964:	learn: 0.0825786	total: 1m 34s	remaining: 3.44s
# 965:	learn: 0.0825256	total: 1m 34s	remaining: 3.34s
# 966:	learn: 0.0824423	total: 1m 34s	remaining: 3.24s
# 967:	learn: 0.0823582	total: 1m 35s	remaining: 3.14s
# 968:	learn: 0.0822415	total: 1m 35s	remaining: 3.04s
# 969:	learn: 0.0821469	total: 1m 35s	remaining: 2.95s
# 970:	learn: 0.0820695	total: 1m 35s	remaining: 2.85s
# 971:	learn: 0.0819852	total: 1m 35s	remaining: 2.75s
# 972:	learn: 0.0818576	total: 1m 35s	remaining: 2.65s
# 973:	learn: 0.0817581	total: 1m 35s	remaining: 2.55s
# 974:	learn: 0.0816182	total: 1m 35s	remaining: 2.46s
# 975:	learn: 0.0814709	total: 1m 35s	remaining: 2.36s
# 976:	learn: 0.0813042	total: 1m 36s	remaining: 2.26s
# 977:	learn: 0.0812474	total: 1m 36s	remaining: 2.16s
# 978:	learn: 0.0811845	total: 1m 36s	remaining: 2.06s
# 979:	learn: 0.0811165	total: 1m 36s	remaining: 1.97s
# 980:	learn: 0.0810488	total: 1m 36s	remaining: 1.87s
# 981:	learn: 0.0809285	total: 1m 36s	remaining: 1.77s
# 982:	learn: 0.0808350	total: 1m 36s	remaining: 1.67s
# 983:	learn: 0.0807797	total: 1m 36s	remaining: 1.57s
# 984:	learn: 0.0806511	total: 1m 36s	remaining: 1.47s
# 985:	learn: 0.0805815	total: 1m 36s	remaining: 1.38s
# 986:	learn: 0.0805056	total: 1m 36s	remaining: 1.28s
# 987:	learn: 0.0803369	total: 1m 37s	remaining: 1.18s
# 988:	learn: 0.0802089	total: 1m 37s	remaining: 1.08s
# 989:	learn: 0.0800503	total: 1m 37s	remaining: 983ms
# 990:	learn: 0.0799381	total: 1m 37s	remaining: 884ms
# 991:	learn: 0.0798300	total: 1m 37s	remaining: 786ms
# 992:	learn: 0.0797397	total: 1m 37s	remaining: 688ms
# 993:	learn: 0.0796525	total: 1m 37s	remaining: 589ms
# 994:	learn: 0.0795189	total: 1m 37s	remaining: 491ms
# 995:	learn: 0.0793942	total: 1m 37s	remaining: 393ms
# 996:	learn: 0.0791911	total: 1m 37s	remaining: 295ms
# 997:	learn: 0.0790062	total: 1m 38s	remaining: 196ms
# 998:	learn: 0.0789084	total: 1m 38s	remaining: 98.2ms
# 999:	learn: 0.0788195	total: 1m 38s	remaining: 0us
# Accuracy (Training Data): 0.9993326659993327
# Precision (Training Data): 0.9993337491930748
# Recall (Training Data): 0.9993326659993327
# F1 Score (Training Data): 0.9993326605834665
#
# Accuracy (Testing Data): 0.8928928928928929
# Precision (Testing Data): 0.8926579818144235
# Recall (Testing Data): 0.8928928928928929
# F1 Score (Testing Data): 0.8924781602804163
# Accuracy (Training Data): 0.4806473139806473
# Precision (Training Data): 0.47788903084552825
# Recall (Training Data): 0.4806473139806473
# F1 Score (Training Data): 0.4557229853439726
#
# Accuracy (Testing Data): 0.48098098098098097
# Precision (Testing Data): 0.481903839428182
# Recall (Testing Data): 0.48098098098098097
# F1 Score (Testing Data): 0.45476585462614005
# Accuracy (Training Data): 0.9993326659993327
# Precision (Training Data): 0.9993326659993327
# Recall (Training Data): 0.9993326659993327
# F1 Score (Training Data): 0.9993326659993327
#
# Accuracy (Testing Data): 0.8881381381381381
# Precision (Testing Data): 0.8888736255265827
# Recall (Testing Data): 0.8881381381381381
# F1 Score (Testing Data): 0.8880590590737099
# Best Parameters: {'solver': 'adam', 'max_iter': 15000, 'hidden_layer_sizes': (100,), 'alpha': 0.1, 'activation': 'relu'}
# Best Score: 0.2876189256211005
#
# Accuracy (Testing Data): 0.8518518518518519
# C:\Users\USER\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:962: UserWarning: The figure layout has changed to tight
#   pl.tight_layout()
# C:\Users\USER\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:636: UserWarning: The figure layout has changed to tight
#   pl.tight_layout(pad=0, w_pad=0, h_pad=0.0)
